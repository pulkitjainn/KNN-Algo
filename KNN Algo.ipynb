# %%
# KNN ALGO 
# for predicting the whether the given fruit results is an apple or a lemmon
# two inputs are provided for calculating the answer
#Output 1 : Lemon
#Output 0 : Apple

# %%
import math
import numpy as np
from matplotlib import pyplot as plt
from jupyterthemes import jtplot
jtplot.style()

# %%
a = np.asarray(range(100))

plt.figure(0)
plt.plot(a)
plt.show()

# %%
mean_01 = np.array([3.0,4.0])

cov_01 = np.array([[1.0,-0.5],[-0.5,1.0]])


mean_02 = np.array([0.0,0.0])

cov_02 = np.array([[1.0,0.5],[0.5,0.6]])


dist_01 = np.random.multivariate_normal(mean_01,cov_01,200)
dist_02 = np.random.multivariate_normal(mean_02,cov_02,200)


#print (dist_01.shape)
#print (dist_01)

# %%
plt.figure(0)

for x in range(dist_01.shape[0]):
    plt.scatter(dist_01[x,0],dist_01[x,1],color='red')
    plt.scatter(dist_02[x,0],dist_02[x,1],color='yellow')

plt.show()

# %%
labels = np.zeros((400,1))
labels[200:] = 1.0

X_data = np.zeros((400,2))
X_data[:200,:] = dist_01
X_data[200: ,:] = dist_02

#print (X_data)
#print (labels)

# %%
def dist(x1,x2):
    return np.sqrt(((x1-x2)**2).sum())

# %%
def knn(X_train,query_point,Y_train,k=5):
    vals = []
    for ix in range(X_train.shape[0]):
        v = [ dist(query_point,X_train[ix,:]),Y_train[ix]]
        vals.append(v)
        
   
    updated_list = sorted(vals)
        
    pred_arr = np.asarray(updated_list[:k])
    pred_arr = np.unique(pred_arr[:,1],return_counts = True)
    
    index = pred_arr[1].argmax()
    return pred_arr[0][index]
    
q = np.array([2.0,2.0])
print (knn(X_data,q,labels))
# Out:
# 0.0
